# %% [markdown]
# #### Standard imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Performing a Type 1 ANOVA
# Question 23 : Using penguins.csv, write the code to perform a Type 1 ANOVA to determine how much the variance in body_mass_g is explained by the bill_length_mm, bill_depth_mm, and flipper_length_mm variables across all observations in the dataset. Use the function from statsmodels.api.sm.stats.anova_lm. Are any of the variables statistically insignificant?

# %%
df = pd.read_csv('penguins.csv')
penguins_lm = ols('body_mass_g ~ bill_length_mm + flipper_length_mm', data = df).fit()
table = sm.stats.anova_lm(penguins_lm, typ = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-e6f8ee09cb10> in <module>
#       1 df = pd.read_csv('penguins.csv')
# ----> 2 penguins_lm = ols('body_mass_g ~ bill_length_mm + flipper_length_mm', data = df).fit()
#       3 table = sm.stats.anova_lm(penguins_lm, typ = 1)
#
# NameError: name 'ols' is not defined
